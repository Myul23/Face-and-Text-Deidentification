# %%
from glob import glob
import torch

# %%
model_path = "runs/train/exp4/weights/best.pt"
# images = glob("test/images/*")
images = ["test/images/F.jpg", "test/images/A.jpg"]

# %%
model = torch.hub.load('ultralytics/yolov3', 'yolov3')
# model = torch.load(model_path)
# Out:
# Using cache found in C:\Users\User/.cache\torch\hub\ultralytics_yolov3_master
# YOLOv3  2022-5-5 torch 1.11.0+cpu CPU
#
# Fusing layers...
# Model Summary: 261 layers, 61922845 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# 지금 TheModelClass를 정의하기 어려워서 hub에 있는 model을 가져와 대신 정의시키고 구성했음.
# 구성이 같으므로 이후에 load를 통해 불러오려고 했는데, 현재 GPU가 학습 중인 관계로 CPU로 학습된다고 선택되는 바람에 학습된 model과 config가 달라져서 오류가 생김.

# %%
results = model(images)
# Out:
# c:\ProgramData\Anaconda3\lib\site-packages\torch\autocast_mode.py:162: UserWarning: User provided device_type of 'cuda', but CUDA is not available. Disabling
#   warnings.warn('User provided device_type of \'cuda\', but CUDA is not available. Disabling')

# %%
results.print()
# Out:
# image 1/2: 1332x1920 13 apples, 1 orange
# image 2/2: 1440x1920 (no detections)
# Speed: 83.8ms pre-process, 655.2ms inference, 7.5ms NMS per image at shape (2, 3, 480, 640)

# %%
results.show()

# %%
results.crop()
# Out:
# Saved 2 images to runs\detect\exp
# Saved results to runs\detect\exp
# [{'box': [tensor(517.52875),
#    tensor(794.02997),
#    tensor(562.43597),
#    tensor(844.91095)],
#   'conf': tensor(0.29653),
#   'cls': tensor(47.),
#   'label': 'apple 0.30',
#   'im': array([[[ 53, 122,  17],
#           [ 55, 126,  16],
#           [ 53, 125,  19],
#           ...,
#           [134, 219,  61],
#           [134, 219,  61],
#           [134, 219,  61]],
#
#          [[ 52, 121,  16],
#           [ 53, 124,  14],
#           [ 52, 123,  20],
#           ...,
#           [159, 226, 101],
#           [159, 226, 101],
#           [162, 228, 106]],
#
#          [[ 53, 122,  19],
#           [ 51, 121,  14],
#           [ 50, 121,  18],
#           ...,
#           [255, 255, 255],
#           [255, 255, 255],
#           [255, 255, 255]],
#
#          ...,
#
#          [[ 58, 128,  35],
#           [106, 163, 102],
#           [150, 191, 170],
#           ...,
#           [ 42,  56,  62],
# ...
